# %% [markdown]
# # Tarea 3: Métricas para la evaluación de modelos de aprendizaje supervisado
#
#     Para poder evaluar si nuestro modelo generaliza correctamente es necesario podemos aplicar ciertas métricas dependiendo del problema que queremos resolver y acontinuación vamos a explicar en detalle cada una de ellas.
#
# ### Integrantes:
#
#     - Javier Vega
#     - Erick Calvo

# %% [markdown]
# ##### Evaluación de modelos de clasificación.
#
#      1. Matriz de confusión.
#      2. Exactitud o Accuracy.
#      3. Precision.
#      4. Sencibilidad o Recall.
#      5. Especificidad.
#      6. F1 score.
#      7. Curva de características operativas del receptor (ROC).
#      8. Pérdida logarítmica.

# %% [markdown]
# ##### Evaluación de modelos de regresión.
#
#     1. Error medio absoluto.
#     2. Error cuadrático medio.
#     3. Raíz del error cuadrático medio.
#     4. R cuadrado (coeficiente de determinación).
#     5. R cuadrado ajustado.

# %% [markdown]
# ### Metricas para modelos de clasificación
#
# ##### Matriz de confusión:
# Se utiliza para representar gráficamente las predicciones de nuestro modelo. Las columnas representan el número de predicciones de cada clase, mientras que las filas son las instancias en la clase real.
# En caso de que tenga solo dos clases se le conoce como matriz binaria y permite definir el conjunto de muestras que veremos a continuación apartir de los posibles cuatro resultados que arroja:
#
# - Verdadero Positivo (TP): Predicho Verdadero y Verdadero en realidad.
# - Verdadero Negativo (TN): Predicho Falso y Falso en realidad.
# - Falso Positivo (FP): Predicción de verdadero y falso en la realidad.
# - Falso Negativo (FN): Predicción de falso y verdadero en la realidad.
# ![matriz-2.png](attachment:matriz-2.png)

# %%
#Ejemplo tomado de: 
#https://www.datasource.ai/es/data-science-articles/metricas-de-evaluacion-de-modelos-en-el-aprendizaje-automatico

import warnings
import pandas as pd
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline  

#ignore warnings
warnings.filterwarnings('ignore')
# Load digits dataset
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df = pd.read_csv(url)
# df = df.values
X = df.iloc[:,0:4]
y = df.iloc[:,4]
#test size
test_size = 0.33
#generate the same set of random numbers
seed = 7
#Split data into train and test set. 
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=seed)
#Train Model
model = LogisticRegression()
model.fit(X_train, y_train)
pred = model.predict(X_test)

#Construct the Confusion Matrix
labels = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
cm = confusion_matrix(y_test, pred, labels)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()
# Out:
# [[13  0  0]
#  [ 0 17  2]
#  [ 0  0 18]]

# %% [markdown]
# ##### Exactitud o Accuracy:
# Se define como el porcentaje de predicciones correctas hechas por el modelo, es una buena métrica de evaluación cuando las clases estan balanceadas:
#
# \begin{equation}
# Accuracy=\frac{TN+TP}{TN+TP+FN+FP}.
# \end{equation}

# %%
#Ejemplo tomado de: 
#https://www.datasource.ai/es/data-science-articles/metricas-de-evaluacion-de-modelos-en-el-aprendizaje-automatico


#import modules
import warnings
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn.metrics import accuracy_score
#ignore warnings
warnings.filterwarnings('ignore')
# Load digits dataset
iris = datasets.load_iris()
# # Create feature matrix
X = iris.data
# Create target vector
y = iris.target
#test size
test_size = 0.33
#generate the same set of random numbers
seed = 7
#cross-validation settings
kfold = model_selection.KFold(n_splits=10, random_state=None)
#Model instance
model = LogisticRegression()
#Evaluate model performance
scoring = 'accuracy'
results = model_selection.cross_val_score(model, X, y, cv=kfold, scoring=scoring)
print('Accuracy -val set: %.2f%% (%.2f)' % (results.mean()*100, results.std()))

#split data
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=seed)
#fit model
model.fit(X_train, y_train)
#accuracy on test set
result = model.score(X_test, y_test)
print("Accuracy - test set: %.2f%%" % (result*100.0))
# Out:
# Accuracy -val set: 94.67% (0.06)
# Accuracy - test set: 92.00%

# %% [markdown]
# ##### Precision:
# Es la relación porcentual entre las predicciones positivas verdaderas y las predicciones positivas totales (incluyen las falsas positivas):
#
# \begin{equation}
# Precision=\frac{TP}{TP+FP}.
# \end{equation}

# %% [markdown]
# ##### Sencibilidad o Recall:
# Es la relación porcentual entre las predicciones positivas verdaderas y número total de casos positivos:
#
# \begin{equation}
# Recall=\frac{TP}{TP+FN}.
# \end{equation}

# %% [markdown]
# ##### Especificidad:
# Es la relación porcentual entre las predicciones negativas verdaderas y número total de casos negativos:
#
# \begin{equation}
# Specificity=\frac{TN}{TN+FP}.
# \end{equation}

# %% [markdown]
# Cuando las clases no estan balanceadas se recomienda usar Presición o Sencibilidad en vez de Exactitud. Si la idea es enfocarnos en evitar falsos positivos podríamos optar por Presición y si por el contrario sería disminuir los falsos negativos deberiamos utilizar Sencibilidad. Sin embargo si la idea es tener un balance entre ambos podríamos optar por la siguiente métrica:

# %% [markdown]
# ##### F1 score:
# Es la combinación de las métricas de Presición y Recall o Sencibilidad:
#
# \begin{equation}
# F1=2*\frac{Presicion×Recall}{Presicion+Recall}.
# \end{equation}

# %%
#Ejemplo tomado de: 
#https://www.datasource.ai/es/data-science-articles/metricas-de-evaluacion-de-modelos-en-el-aprendizaje-automatico

import warnings
import pandas
from sklearn import model_selection
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
from sklearn.metrics import precision_recall_fscore_support as score, precision_score, recall_score, f1_score

warnings.filterwarnings('ignore')

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
dataframe = pandas.read_csv(url)
dat = dataframe.values
X = dat[:,:-1]
y = dat[:,-1]
test_size = 0.33
seed = 7

model = LogisticRegression()
#split data
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=seed)

model.fit(X_train, y_train)
pred = model.predict(X_test)

precision = precision_score(y_test, pred)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, pred)
print('Recall: %f' % recall)
# f1: tp / (tp + fp + fn)
f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)
# Out:
# Precision: 0.701493
# Recall: 0.552941
# F1 score: 0.618421

# %% [markdown]
# ##### Curva de características operativas del receptor (ROC):
# Esta curva permite visualizar el equilibrio entre la tasa de verdaderos positivos y la tasa falsos positivos, se obtiene al trazar la tasa positiva verdadera (sensibilidad) frente a la tasa de falsos positivos (1 - especificidad).
#
# \begin{equation}
# ROC=\frac{Recall}{1- Specificity}.
# \end{equation}
#
# ##### El área bajo la curva (AUC):
# Esta dada a partir de la curva ROC y entre más alta es la AUC indica que mejor es el rendimiento del modelo para distinguir entre clases positivas y negativas.
# ![auc.jpg](attachment:auc.jpg)

# %%
#Ejemplo tomado de: 
#https://www.datasource.ai/es/data-science-articles/metricas-de-evaluacion-de-modelos-en-el-aprendizaje-automatico

#Classification Area under curve
import warnings
import pandas
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, roc_curve

warnings.filterwarnings('ignore')

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
dataframe = pandas.read_csv(url)
dat = dataframe.values
X = dat[:,:-1]
y = dat[:,-1]
seed = 7
#split data
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=seed)
model.fit(X_train, y_train)

# predict probabilities
probs = model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]

auc = roc_auc_score(y_test, probs)
print('AUC - Test Set: %.2f%%' % (auc*100))

# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
plt.xlabel('False positive rate')
plt.ylabel('Sensitivity/ Recall')
# show the plot
plt.show()
# Out:
# AUC - Test Set: 82.85%

# %% [markdown]
# ##### Pérdida logarítmica:
# A medida que la probabilidad predicha de la clase verdadera se acerca a cero, la pérdida aumenta exponencialmente. Mide el desempeño de un modelo de clasificación en el que la entrada de la predicción es un valor de probabilidad entre 0 y 1.
# ![PL.png](attachment:PL.png)

# %%
#Ejemplo tomado de: 
#https://www.datasource.ai/es/data-science-articles/metricas-de-evaluacion-de-modelos-en-el-aprendizaje-automatico

#Classification LogLoss
import warnings
import pandas
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss

warnings.filterwarnings('ignore')
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
dataframe = pandas.read_csv(url)
dat = dataframe.values
X = dat[:,:-1]
y = dat[:,-1]
seed = 7
#split data
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=seed)
model.fit(X_train, y_train)
#predict and compute logloss
pred = model.predict(X_test)
accuracy = log_loss(y_test, pred)
print("Logloss: %.2f" % (accuracy))
# Out:
# Logloss: 7.89

# %% [markdown]
# ### Metricas para modelos de regresión
#
# ##### Error medio absoluto:
# Es el valor medio de la diferencia absoluta entre el valor real y el valor predicho:
#
# \begin{equation}
# MAE=\frac{1}{N}\sum_{i=1}^{N}|y_i−ŷ_i|
# \end{equation}

# %%
#Ejemplo de MAE (Error medio absoluto).

from sklearn.metrics import mean_absolute_error
y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
mae = mean_absolute_error(y_true, y_pred)
mae
# Out:
# 0.5

# %% [markdown]
# #####  Error cuadrático medio:
# Es el valor medio de la diferencia al cuadrado entre el valor real y el predicho:
#
# \begin{equation}
# MSE=\frac{1}{N}\sum_{i=1}^{N}(y_i−ŷ_i)^2
# \end{equation}
#
# - Destaca grandes errores entre los pequeños.
# - Ayuda a encontrar los valores mínimos y máximos utilizando los métodos matemáticos de manera más efectiva.

# %%
#Ejemplo de MSE (Error cuadrático medio).

from sklearn.metrics import mean_squared_error
y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
mse = mean_squared_error(y_true, y_pred)
mse
# Out:
# 0.375

# %% [markdown]
# #####  Raíz del error cuadrático medio:
# Es la raíz cuadrada del error cuadrático medio:
#
# \begin{equation}
# RMSE=\sqrt{\frac{1}{N}\sum_{i=1}^{N}(y_i−ŷ_i)^2}
# \end{equation}
#
# - Utiliza valores absolutos más pequeños, lo que es ideal para los cálculos informáticos.

# %%
#Ejemplo de RMSE (Raíz del error cuadrático medio).

import numpy as np
from sklearn.metrics import mean_squared_error
y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
rmse = np.square(mean_squared_error(y_true, y_pred))
rmse
# Out:
# 0.140625

# %% [markdown]
# #####   R cuadrado (coeficiente de determinación):
# Compara la media de los errores al cuadrado (MSE) de nuestro modelo con la MSE de un modelo básico que siempre devuelve como predicción la media de los valores de entrenamiento.
#
# \begin{equation}
# R^2=1-\frac{\sum_{i=1}^{N}(y_i−ŷ_i)^2}{\sum_{i=1}^{N}(y_i−\bar{y}_i)^2}
# \end{equation}
#
# - Tiene un problema y es que entre más variables independientes se le agreguen al modelo el cálculo de R cuadrado se queda igual o mejora, nunca empeora lo cual no siempre es correcto. Para evitar esto se utiliza la siguiente métrica.

# %%
#Ejemplo de R cuadrado (coeficiente de determinación).

from sklearn.metrics import r2_score
y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
r2 = r2_score(y_true, y_pred)
r2
# Out:
# 0.9486081370449679

# %% [markdown]
# #####   R cuadrado ajustado:
# Indica que porcentaje de variación de la variable dependiente es explicado colectivamente por todas las variables independientes.
#
# \begin{equation}
# \bar{R}^2=1-\frac{N-1}{N-k-1}(1-R^2)
# \end{equation}
#
# - N: número de observaciones de la muestra.
# - k: número de variables independientes.

# %%
#Ejemplo de R ajustado (coeficiente de determinación ajustado).

from sklearn. linear_model  import LinearRegression
import pandas as pd

#define la URL donde se encuentra el conjunto de datos
url = "https://raw.githubusercontent.com/Statology/Python-Guides/main/mtcars.csv"

#leer en datos
data = pd. read_csv (url)

#fit modelo de regresión model
model = LinearRegression ()
X, y = data [["mpg", "wt", "drat", "qsec"]], data.hp
model.fit(X, y)

# mostrar R cuadrado ajustado
r2a = 1 - (1-model.score(X, y)) * ( len (y) -1) / ( len (y) -X.shape [1] -1)
r2a
# Out:
# 0.7787005290062519

# %% [markdown]
# ### Analisis de los Modelos para un dataset en particular

# %% [markdown]
# > Para el ejercicio de la tarea se requiere seleccionar un dataset para poder analizar el uso en los diferentes algoritmos ya vistos

# %% [markdown]
# > Escogimos un dataset que nos parecio interseante debido a los features explicados sobre todo en que signfica cada uno para poder entender que caracteristicas son mas importantes
# > y que tanto puede variar el uso de uno y u otra
# > El caso es predecir a travez de ciertas caracteristas exteriores particulares de un conjunto de de tipos de hongos si son venenosos o no

# %% [markdown]
# ##### Librerías de Python requeridas:
#
#     A continuación se presentan la lista de librerías que se requieren para llevar a cabo las tareas de preprocesamiento solicitadas:
#         1. pandas
#         2. numpy
#         3. sklean
#         4. torch
#         5. matplotlib
#         6. seaborn

# %%
#Importar todas las librerias requeridas

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import torch 
import matplotlib.pyplot as plt
import seaborn as sns

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# ##### Carga de Datos:
#
#     Se cargan los datos del dataset de mushroom.csv

# %%
#Cargar los datos 

hongos_dt = pd.read_csv("mushrooms.csv")

# %% [markdown]
# ##### Visualización de Datos:
#
#     Se visualizan las primeras filas de datos del datase, se puede hacer una visualizacion rapida
#     atravez de la funcion head, que recibe como parametro la cantidad de registros que despliegan

# %%
#Visualización de datos:

hongos_dt.head(200)
# Out:
#     class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0       p         x           s         n       t    p               f
# 1       e         x           s         y       t    a               f
# 2       e         b           s         w       t    l               f
# 3       p         x           y         w       t    p               f
# 4       e         x           s         g       f    n               f
# ..    ...       ...         ...       ...     ...  ...             ...
# 195     e         f           f         g       f    n               f
# 196     e         b           s         y       t    a               f
# 197     e         x           s         w       t    l               f
# 198     e         x           y         w       t    l               f
# 199     e         f           s         w       t    a               f
#
#     gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0              c         n          k  ...                        s
# 1              c         b          k  ...                        s
# 2              c         b          n  ...                        s
# 3              c         n          n  ...                        s
# 4              w         b          k  ...                        s
# ..           ...       ...        ...  ...                      ...
# 195            c         n          g  ...                        s
# 196            c         b          n  ...                        s
# 197            c         b          g  ...                        s
# 198            c         b          n  ...                        s
# 199            w         n          n  ...                        s
#
#     stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                        w                      w         p          w
# 1                        w                      w         p          w
# 2                        w                      w         p          w
# 3                        w                      w         p          w
# 4                        w                      w         p          w
# ..                     ...                    ...       ...        ...
# 195                      w                      w         p          w
# 196                      w                      w         p          w
# 197                      w                      w         p          w
# 198                      w                      w         p          w
# 199                      w                      w         p          w
#
#     ring-number ring-type spore-print-color population habitat
# 0             o         p                 k          s       u
# 1             o         p                 n          n       g
# 2             o         p                 n          n       m
# 3             o         p                 k          s       u
# 4             o         e                 n          a       g
# ..          ...       ...               ...        ...     ...
# 195           o         p                 n          y       u
# 196           o         p                 k          s       g
# 197           o         p                 n          n       m
# 198           o         p                 n          s       m
# 199           o         p                 n          v       d
#
# [200 rows x 23 columns]

# %% [markdown]
# ##### Descripcion de las caracteristicas

# %% [markdown]
# ##### Attribute Information: (classes: edible = e, poisonous = p)
#
# 1. cap-shape: bell = b, conical = c,convex = x, flat = f, knobbed = k, sunken = s
# 2. cap-surface: fibrous = f, grooves = g, scaly = y, smooth = s
# 3. cap-color: brown = n, buff = b, cinnamon = c, gray = g, green = r, pink = p, purple = u, red = e, white = w, yellow = y
# 4. bruises: yes = t, no = f
# 5. odor: almond = a, anise = l, creosote = c, fishy = y, foul = f, musty = m, none = n, pungent = p, spicy = s
# 6. gill-attachment: attached = a, descending = d, free = f, notched = n
# 7. gill-spacing: close = c, crowded = w, distant = d
# 8. gill-size: broad = b, narrow = n
# 9. gill-color: black = k, brown = n, buff = b, chocolate = h, gray = g, green = r, orange = o, pink = p, purple = u, red = e, white = w ,yellow = y
# 10. stalk-shape: enlarging = e, tapering = t
# 11. stalk-rootbulbous = b, club = c, cup = u, equal = e, rhizomorphs = z, rooted = r, missing = ?
# 12. stalk-surface-above-ring: fibrous = f, scaly = y, silky = k, smooth = s
# 13. stalk-surface-below-ring: fibrous = f, scaly = y, silky = k, smooth = s
# 14. stalk-color-above-ring: brown = n, buff = b, cinnamon = c, gray = g, orange = o, pink = p, red = e, white = w, yellow = y
# 15. stalk-color-below-ring: brown = n, buff = b, cinnamon = c, gray = g, orange = o, pink = p, red = e, white = w, yellow = y
# 16. veil-type: partial = p, universal = u
# 17. veil-color: brown = n, orange = o, white = w, yellow = y
# 18. ring-number: none = n, one = o, two = t
# 19. ring-type: cobwebby = c, evanescent = e, flaring = f, large = l, none = n, pendant = p, sheathing = s, zone = z
# 20. spore-print-color: black = k, brown = n, buff = b, chocolate = h, green = r, orange = o,purple = u, white = w, yellow = y
# 21. population: abundant = a, clustered = c, numerous = n, scattered = s, several = v, solitary = y
# 22. habitat: grasses = g, leaves = l, meadows = m, paths = p, urban = u, waste = w, woods = d

# %% [markdown]
# ##### Descripcion grafica de las caracteristicas

# %% [markdown]
# <img src="morphology.jpg">

# %% [markdown]
# ##### Análisis exploratorio de Datos:
#
#     La idea es poder visualizar los datos, es importante tener una idea de lo que se requiere analizar, en este caso con las caracteristicas visibles como forma, color de las partes o su distribucion en la naturaleza se trata de predecir si es o no venenoso.

# %%
#Visualización de las principales estadísticas del dataset.

hongos_dt.head(200)
# Out:
#     class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0       p         x           s         n       t    p               f
# 1       e         x           s         y       t    a               f
# 2       e         b           s         w       t    l               f
# 3       p         x           y         w       t    p               f
# 4       e         x           s         g       f    n               f
# ..    ...       ...         ...       ...     ...  ...             ...
# 195     e         f           f         g       f    n               f
# 196     e         b           s         y       t    a               f
# 197     e         x           s         w       t    l               f
# 198     e         x           y         w       t    l               f
# 199     e         f           s         w       t    a               f
#
#     gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0              c         n          k  ...                        s
# 1              c         b          k  ...                        s
# 2              c         b          n  ...                        s
# 3              c         n          n  ...                        s
# 4              w         b          k  ...                        s
# ..           ...       ...        ...  ...                      ...
# 195            c         n          g  ...                        s
# 196            c         b          n  ...                        s
# 197            c         b          g  ...                        s
# 198            c         b          n  ...                        s
# 199            w         n          n  ...                        s
#
#     stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                        w                      w         p          w
# 1                        w                      w         p          w
# 2                        w                      w         p          w
# 3                        w                      w         p          w
# 4                        w                      w         p          w
# ..                     ...                    ...       ...        ...
# 195                      w                      w         p          w
# 196                      w                      w         p          w
# 197                      w                      w         p          w
# 198                      w                      w         p          w
# 199                      w                      w         p          w
#
#     ring-number ring-type spore-print-color population habitat
# 0             o         p                 k          s       u
# 1             o         p                 n          n       g
# 2             o         p                 n          n       m
# 3             o         p                 k          s       u
# 4             o         e                 n          a       g
# ..          ...       ...               ...        ...     ...
# 195           o         p                 n          y       u
# 196           o         p                 k          s       g
# 197           o         p                 n          n       m
# 198           o         p                 n          s       m
# 199           o         p                 n          v       d
#
# [200 rows x 23 columns]

# %% [markdown]
# forma del dataset

# %%
hongos_dt.shape
# Out:
# (8124, 23)

# %% [markdown]
# un dataset de 8124 filas por 23 columnas

# %% [markdown]
#     Revisando los datos podemos darnos cuenta que el set presenta algunos problemas, hay algunos atributos que estan en formato de texto, que se puede categorizar por numero por ejemplo el atributo de class (p,e) entre comestible y no comestible

# %% [markdown]
# ##### Pasar los atributos texto a número:
#
#     En este caso como podemos observar el dataset contiene algunas columnas que tienen valores tipo texto las cuales debemos convertir en valores númericos:
#         1. La idea sería cambiar mediante OrdinalEncoder de sklearn.

# %% [markdown]
# ##### Utilización de LabelEncoder:
#
#     A continuación se muestra como se utiliza OrdinalEncoder de sklearn para cambiar los valores de los atributos de tipo texto a número.

# %%
# Utilizar OrdinalEncoder de sklearn para cambiar los datos a datos numéricos

from sklearn.preprocessing import LabelEncoder
hongos_encoded = hongos_dt.apply(LabelEncoder().fit_transform)

# %% [markdown]
# Manejo de valores NAN, en el caso de querer eliminar las columnas o filas  que tengan valores Nan se puede ejecutar

# %%
#en este caso para la columna agente se elimina datos Nan
hongos_encoded = hongos_encoded.dropna() 
#visualizacion despues de los cambios

# %% [markdown]
# ### Mapa de Correlacion
# ##
# > Es una herramienta gráfica que permite demostrar la relación existente entre dos clases de datos y cuantificar la intensidad de dicha relación.
# >
# > Se utiliza para conocer si efectivamente existe una correlación entre dos magnitudes o parámetros de un problema y, en caso positivo, de qué tipo es la correlación

# %%
def correlation_heatmap(df1):
    _,ax=plt.subplots(figsize=(15,10))
    colormap=sns.diverging_palette(220,10,as_cmap=True)
    sns.heatmap(df1.corr(),annot=True,cmap=colormap)
    
correlation_heatmap(hongos_encoded)

# %% [markdown]
# ### PairPlot
# >Esta función crea una cuadrícula de ejes de modo que cada variable numérica en los datos se compartirá entre los ejes y en una sola fila y los ejes x en una sola columna

# %%
fig = plt.figure(figsize = (25,18))
#obtener ejes polares
ax = fig.gca()
hongos_encoded.hist(ax=ax)
plt.show()

# %% [markdown]
# ##### Separacion de Columnas Features y Targets

# %% [markdown]
# Despues del Analizis nos damos cuenta que la columna class que distingue entre comestible y no comestible seria nuestra columna target y las demas columnas target

# %%
hongos_features = hongos_encoded.iloc[:, 1:33]

# %%
hongos_features.head(100)
# Out:
#     cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0           5            2          4        1     6                1
# 1           5            2          9        1     0                1
# 2           0            2          8        1     3                1
# 3           5            3          8        1     6                1
# 4           5            2          3        0     5                1
# ..        ...          ...        ...      ...   ...              ...
# 95          5            2          8        1     0                1
# 96          2            3          4        1     3                1
# 97          5            2          9        1     0                1
# 98          0            2          8        1     0                1
# 99          5            3          8        1     0                1
#
#     gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0              0          1           4            0  ...
# 1              0          0           4            0  ...
# 2              0          0           5            0  ...
# 3              0          1           5            0  ...
# 4              1          0           4            1  ...
# ..           ...        ...         ...          ...  ...
# 95             0          0           2            0  ...
# 96             0          0           7            0  ...
# 97             0          0           5            0  ...
# 98             0          0           2            0  ...
# 99             0          0           2            0  ...
#
#     stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                          2                       7                       7
# 1                          2                       7                       7
# 2                          2                       7                       7
# 3                          2                       7                       7
# 4                          2                       7                       7
# ..                       ...                     ...                     ...
# 95                         2                       7                       7
# 96                         3                       7                       7
# 97                         2                       7                       7
# 98                         2                       7                       7
# 99                         2                       7                       7
#
#     veil-type  veil-color  ring-number  ring-type  spore-print-color  \
# 0           0           2            1          4                  2
# 1           0           2            1          4                  3
# 2           0           2            1          4                  3
# 3           0           2            1          4                  2
# 4           0           2            1          0                  3
# ..        ...         ...          ...        ...                ...
# 95          0           2            1          4                  3
# 96          0           2            1          4                  3
# 97          0           2            1          4                  2
# 98          0           2            1          4                  3
# 99          0           2            1          4                  2
#
#     population  habitat
# 0            3        5
# 1            2        1
# 2            2        3
# 3            3        5
# 4            0        1
# ..         ...      ...
# 95           3        1
# 96           3        1
# 97           2        1
# 98           3        1
# 99           3        1
#
# [100 rows x 22 columns]

# %%
hongos_target = hongos_encoded['class']
hongos_target.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int32

# %% [markdown]
# ##### Normalizacion de datos:
# ##
# >Normalizacion es una tecnica aplicada para la preparacion de datos, el objetivo es cambiar los valores de columnas numericas en un datase a una escala
# >
# >comun, y asi evitar distorciones en el rango de valores

# %% [markdown]
# Visualizacion para ver los datos antes de la normalizacion

# %% [markdown]
# Normalizemos el dataframe para ver como cambia la relacion de los datos

# %%
def normalizacion_max_min(df):
    
    df_scaled = df.copy() # se realiza una copia del dataframe
    # se aplica max min 
    for column in df_scaled.columns: # por cada columna del dataframe
        df_scaled[column] = df_scaled[column]  / df_scaled[column].abs().max() #aplicar la normalizacion
    return df_scaled

hongos_df_norm = normalizacion_max_min(hongos_encoded)

hongos_df_norm= hongos_df_norm.dropna(axis=1) 

hongos_df_norm =hongos_df_norm.reset_index(drop=True)

hongos_target = hongos_df_norm["class"]

hongos_features = hongos_df_norm.iloc[:, 1:33]

# %% [markdown]
# Otra funcion que es util para analizar datos es el uso de **describe** lo cual nos muetra stadisticas como avg, mean, std

# %%
#Visualización de las principales estadísticas del dataset.

hongos_df_norm.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     0.669621     0.609224     0.500520     0.415559
# std       0.499708     0.320866     0.409958     0.282869     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.400000     0.000000     0.333333     0.000000
# 50%       0.000000     0.600000     0.666667     0.444444     0.000000
# 75%       1.000000     1.000000     1.000000     0.888889     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      0.518095         0.974151      0.161497     0.309207     0.437335
# std       0.262966         0.158695      0.368011     0.462195     0.321851
# min       0.000000         0.000000      0.000000     0.000000     0.000000
# 25%       0.250000         1.000000      0.000000     0.000000     0.181818
# 50%       0.625000         1.000000      0.000000     0.000000     0.454545
# 75%       0.625000         1.000000      0.000000     1.000000     0.636364
# max       1.000000         1.000000      1.000000     1.000000     1.000000
#
#        ...  stalk-surface-above-ring  stalk-surface-below-ring  \
# count  ...               8124.000000               8124.000000
# mean   ...                  0.525029                  0.534548
# std    ...                  0.207153                  0.225325
# min    ...                  0.000000                  0.000000
# 25%    ...                  0.333333                  0.333333
# 50%    ...                  0.666667                  0.666667
# 75%    ...                  0.666667                  0.666667
# max    ...                  1.000000                  1.000000
#
#        stalk-color-above-ring  stalk-color-below-ring   veil-color  \
# count             8124.000000             8124.000000  8124.000000
# mean                 0.727043                0.724335     0.655178
# std                  0.237718                0.238411     0.080890
# min                  0.000000                0.000000     0.000000
# 25%                  0.750000                0.750000     0.666667
# 50%                  0.875000                0.875000     0.666667
# 75%                  0.875000                0.875000     0.666667
# max                  1.000000                1.000000     1.000000
#
#        ring-number    ring-type  spore-print-color   population      habitat
# count  8124.000000  8124.000000        8124.000000  8124.000000  8124.000000
# mean      0.534712     0.572994           0.449594     0.728804     0.251436
# std       0.135532     0.450418           0.297833     0.250416     0.286663
# min       0.000000     0.000000           0.000000     0.000000     0.000000
# 25%       0.500000     0.000000           0.250000     0.600000     0.000000
# 50%       0.500000     0.500000           0.375000     0.800000     0.166667
# 75%       0.500000     1.000000           0.875000     0.800000     0.333333
# max       1.000000     1.000000           1.000000     1.000000     1.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# ### Separacion de los datos de entrenamiento

# %%
#esta funcion nos permite dividr los datos de entrenamiento y los de prueba
from sklearn.model_selection import train_test_split


features_training, feature_test, target_training, target_test = train_test_split(
     hongos_features, 
     hongos_target, 
     test_size=0.4,#proporcion del dataset que se utiliza para los datos de prueba
     random_state=42 # un factor que se utiliza a la hora de mezclar los datos antes de aplicar la particion de datos
)

# %% [markdown]
# # RandomFortest Classifier

# %%
##clasificador usando Random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

features_training.head()
# Out:
#       cap-shape  cap-surface  cap-color  bruises   odor  gill-attachment  \
# 7354        0.0     0.666667   0.888889      0.0  0.625              1.0
# 1222        1.0     0.000000   0.333333      0.0  0.625              1.0
# 3375        0.4     0.000000   0.333333      1.0  0.625              1.0
# 6301        0.6     1.000000   0.444444      0.0  1.000              1.0
# 5838        0.4     0.666667   0.333333      1.0  0.250              1.0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 7354           1.0        0.0    0.181818          0.0  ...
# 1222           1.0        0.0    0.363636          1.0  ...
# 3375           0.0        0.0    0.818182          1.0  ...
# 6301           0.0        1.0    0.000000          1.0  ...
# 5838           0.0        0.0    0.636364          1.0  ...
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 7354                  0.666667                  0.333333
# 1222                  0.000000                  0.000000
# 3375                  0.666667                  0.666667
# 6301                  0.333333                  0.666667
# 5838                  0.000000                  0.666667
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-color  ring-number  \
# 7354                   0.875                   0.875    0.666667          1.0
# 1222                   0.875                   0.875    0.666667          0.5
# 3375                   0.875                   0.375    0.666667          0.5
# 6301                   0.750                   0.750    0.666667          0.5
# 5838                   0.875                   0.875    0.666667          0.5
#
#       ring-type  spore-print-color  population   habitat
# 7354        1.0              0.875         0.4  0.166667
# 1222        0.0              0.375         0.0  0.166667
# 3375        1.0              0.250         0.8  0.000000
# 6301        0.0              0.875         0.8  0.666667
# 5838        1.0              0.125         0.6  0.833333
#
# [5 rows x 21 columns]

# %%
target_training.head()
# Out:
# 7354    0.0
# 1222    0.0
# 3375    0.0
# 6301    1.0
# 5838    1.0
# Name: class, dtype: float64

# %%
model_1 = RandomForestClassifier(max_depth=10, random_state=10)
model_1.fit(features_training, target_training)
# Out:
# RandomForestClassifier(max_depth=10, random_state=10)

# %% [markdown]
# ### Prediccion y calculo del accuracy

# %%
y_pred = model_1.predict(feature_test)

# %%
from sklearn.metrics import accuracy_score
#para la parte de la exactitud utilizamos la funcion accuracy_score de sklearn
accuracy_score(target_test,y_pred)
# Out:
# 1.0

# %% [markdown]
# Observando los datos nos podemos dar cuenta que ciertas columnas, como que no tiene relevancia en si a la hora de aplicar el algoritmo

# %%
importances = pd.DataFrame({'feature' : features_training.columns, 'importance':model_1.feature_importances_})
importances = importances.sort_values('importance',ascending=False).set_index('feature')

# %%
importances.head()
# Out:
#                    importance
# feature
# odor                 0.144953
# gill-size            0.144137
# gill-color           0.097379
# spore-print-color    0.088799
# ring-type            0.068782

# %%
importances.plot.bar()
# Out:
# <AxesSubplot:xlabel='feature'>

# %% [markdown]
# Como podemos ver nuestro set de entrenamiento tiene columnas que no son necesarias, por lo cual removiendolas no alteraria el resultado y seria un proceso mas rapido

# %%
features_training.drop(['gill-attachment','gill-color','ring-type','bruises','veil-color','cap-shape'],axis=1)
# Out:
#       cap-surface  cap-color   odor  gill-spacing  gill-size  stalk-shape  \
# 7354     0.666667   0.888889  0.625           1.0        0.0          0.0
# 1222     0.000000   0.333333  0.625           1.0        0.0          1.0
# 3375     0.000000   0.333333  0.625           0.0        0.0          1.0
# 6301     1.000000   0.444444  1.000           0.0        1.0          1.0
# 5838     0.666667   0.333333  0.250           0.0        0.0          1.0
# ...           ...        ...    ...           ...        ...          ...
# 5226     1.000000   0.444444  0.250           0.0        1.0          1.0
# 5390     1.000000   0.222222  0.625           0.0        0.0          0.0
# 860      1.000000   0.444444  0.375           0.0        0.0          0.0
# 7603     0.666667   0.222222  0.250           0.0        1.0          1.0
# 7270     0.000000   0.333333  0.625           1.0        0.0          0.0
#
#       stalk-root  stalk-surface-above-ring  stalk-surface-below-ring  \
# 7354        0.00                  0.666667                  0.333333
# 1222        0.75                  0.000000                  0.000000
# 3375        0.25                  0.666667                  0.666667
# 6301        0.00                  0.333333                  0.666667
# 5838        0.25                  0.000000                  0.666667
# ...          ...                       ...                       ...
# 5226        0.00                  0.333333                  0.666667
# 5390        0.00                  0.666667                  0.666667
# 860         1.00                  0.666667                  1.000000
# 7603        0.00                  0.666667                  0.666667
# 7270        0.00                  0.666667                  0.333333
#
#       stalk-color-above-ring  stalk-color-below-ring  ring-number  \
# 7354                   0.875                   0.875          1.0
# 1222                   0.875                   0.875          0.5
# 3375                   0.875                   0.375          0.5
# 6301                   0.750                   0.750          0.5
# 5838                   0.875                   0.875          0.5
# ...                      ...                     ...          ...
# 5226                   0.750                   0.875          0.5
# 5390                   0.875                   0.250          1.0
# 860                    0.875                   0.875          0.5
# 7603                   0.750                   0.750          0.5
# 7270                   0.875                   0.875          1.0
#
#       spore-print-color  population   habitat
# 7354              0.875         0.4  0.166667
# 1222              0.375         0.0  0.166667
# 3375              0.250         0.8  0.000000
# 6301              0.875         0.8  0.666667
# 5838              0.125         0.6  0.833333
# ...                 ...         ...       ...
# 5226              0.875         0.8  0.666667
# 5390              0.875         0.2  1.000000
# 860               0.375         1.0  0.666667
# 7603              0.875         0.8  0.666667
# 7270              0.875         0.4  0.166667
#
# [4874 rows x 15 columns]

# %%
features_training, feature_test, target_training, target_test = train_test_split(
     hongos_features, 
     hongos_target, 
     test_size=0.4,#proporcion del dataset que se utiliza para los datos de prueba
     random_state=42 # un factor que se utiliza a la hora de mezclar los datos antes de aplicar la particion de datos
)

# %% [markdown]
# #### Aplicacion del modelo

# %%
y_pred = model_1.predict(feature_test)

# %% [markdown]
# #### Aplicando el Accuracy

# %%
from sklearn.metrics import accuracy_score
#para la parte de la exactitud utilizamos la funcion accuracy_score de sklearn
accuracy_score(target_test,y_pred)
# Out:
# 1.0

# %% [markdown]
# no se vio modificado el accuracy_score

# %%
#for windows OS you must install graphviz.gitlab.io/_pages/Download/Download_windows.html
from sklearn.tree import export_graphviz
estimator = model_1.estimators_[0]
export_graphviz(estimator, out_file='complete_tree.dot', feature_names=features_training.columns,impurity=False,class_names=['Venenoso','No Venenoso'],filled=True)

# %%
import pydot

(graph,) = pydot.graph_from_dot_file('complete_tree.dot')
graph.write_png('complete_tree.png')

#esto no funciono 
#from subprocess import call
#check_call(['dot', '-T', 'png', 'complete_tree.dot', '-o', "complete_tree.png"])

# %% [markdown]
# <img src="complete_tree.png">

# %% [markdown]
# ## Aplicacion de Metrica

# %% [markdown]
# ### Confusion Matrix

# %% [markdown]
# Reemplazo de etiquetas

# %%
y_pred_label = np.where(y_pred==0,'Venenoso','No Venenoso')
target_test_label = np.where(target_test==0,'Venenoso','No Venenoso')

# %% [markdown]
# Aplicacion de la matriz

# %%
labels = ['Venenoso', 'No Venenoso']
cm = confusion_matrix(target_test_label, y_pred_label, labels)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

# %% [markdown]
# # Aplicando SVM
#
# Importamos las librerías necesarias

# %%
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# %% [markdown]
# Definimos el parámetro gamma, en este caso como auto.

# %%
svc = SVC(gamma='auto')

# %% [markdown]
# Entrenamos el modelo, con los datos de entrenamiento y pruebas previamente divido.

# %%
svc.fit(features_training, target_training)
# Out:
# SVC(gamma='auto')

# %% [markdown]
# Aplicamos la métrica Accuracy

# %%
print("Accuracy on training set: {:.2f}".format(svc.score(features_training, target_training)))
print("Accuracy on test set: {:.2f}".format(svc.score(feature_test, target_test)))
# Out:
# Accuracy on training set: 0.96
# Accuracy on test set: 0.96

# %% [markdown]
# Podemos visualizar los valores máximos y minimos según los resultados.

# %%
plt.figure(figsize = (25,8))
plt.plot(features_training.min(axis=0), 'o', label="min")
plt.plot(features_training.max(axis=0), '^', label="max")
plt.legend(loc=5)
plt.xlabel("Feature index")
plt.ylabel("Feature magnitude")
# Out:
# Text(0, 0.5, 'Feature magnitude')

# %% [markdown]
# Observamos que obtenemos valores aceptables sin embargo podríamos probar ajustando un poco los hyperparámetros (C=100 y gamma=0.1) para ver el comportamiento.

# %%
svc = SVC(C=100, gamma=0.1)
svc.fit(features_training, target_training)
print("Accuracy on training set: {:.3f}".format(
svc.score(features_training, target_training)))
print("Accuracy on test set: {:.3f}".format(svc.score(feature_test, target_test)))
# Out:
# Accuracy on training set: 1.000
# Accuracy on test set: 1.000

# %% [markdown]
# Observamos que con estos ajustes se mejora aún más la métrica de Accuracy.

# %% [markdown]
# Como quedó evidenciado al aplicar SVM obtenemos muy buenos resultados a la hora de generalizar, por lo tanto sería un método ideal para el tratamiento de este dataset, debido a su alto accuracy podemos inferir que nuestro resultado en la clasificación de hongos venenosos o no venenosos va a tener un resultado muy aceptable.

# %% [markdown]
# #### Aplicacion de la  Metrica

# %% [markdown]
# ##### F1 Score

# %%
precision = precision_score(target_test, y_pred)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(target_test, y_pred)
print('Recall: %f' % recall)
# f1: tp / (tp + fp + fn)
f1 = f1_score(target_test, y_pred)
print('F1 score: %f' % f1)
# Out:
# Precision: 1.000000
# Recall: 1.000000
# F1 score: 1.000000

# %% [markdown]
# # Aplicando KNN
#
# Procedemos a importar la librería necesaría para aplicar el método KNN (KNeighborsClassifier)

# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %% [markdown]
# Inicializamos las listas

# %%
training_accuracy = []
test_accuracy = []

# %% [markdown]
# Creamos la curva de "training/test acurracy vrs. k", para determinar cual sería la mejor opción tomando en cuenta el hiper-parámero k = cantidad de vecinos cercanos para nuestro dataset.
#
# Vamos a utilizar los datos entrenamiento y pruebas previamente dividido.

# %%
plt.style.use('ggplot')
# %matplotlib inline

neighbors_settings = range(1, 12)
for n_neighbors in neighbors_settings:
    # se construye el modelo de clasificacion
    clf = KNeighborsClassifier(n_neighbors=n_neighbors)
    clf.fit(features_training, target_training)
    # se almacena el "training set accuracy"
    training_accuracy.append(clf.score(features_training, target_training))
    # se almacena la "generalization accuracy"
    test_accuracy.append(clf.score(feature_test, target_test))
plt.plot(neighbors_settings, training_accuracy, label="training accuracy")
plt.plot(neighbors_settings, test_accuracy, label="test accuracy")
plt.ylabel("Accuracy")
plt.xlabel("n_neighbors")
plt.legend()

# %% [markdown]
# Revisando la gráfica podemos observar que cuando el k=5 o sea el número de vecinos cercanos es cinco, tiene un accuracy de 1 tanto para el training accuracy como para el testing accuracy, por lo tanto esa sería nuestra mejor opción si queremos utilizar KNN para realizar la clasificación de nuestro dataset de hongos (en venenosos o no venenosos).

# %% [markdown]
# #### Aplicacion de la Metrica

# %% [markdown]
#  ##### Curva de características operativas del receptor (ROC):

# %%
# predict probabilities
import sklearn.metrics as metrics
warnings.filterwarnings('ignore')

ataframe = pandas.read_csv("mushrooms.csv")
dat = dataframe.values
X = dat[:,:-1]
y = dat[:,-1]
seed = 7
#split data
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=seed)
model.fit(X_train, y_train)

# predict probabilities
probs = model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]

auc = roc_auc_score(y_test, probs)
print('AUC - Test Set: %.2f%%' % (auc*100))

# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
plt.xlabel('False positive rate')
plt.ylabel('Sensitivity/ Recall')
# show the plot
plt.show()
# Out:
# AUC - Test Set: 82.85%

# %% [markdown]
# # Métodos de Ensamble
#
# Tienen como objetivo la combinación de varios estimadores base para mejorar la generalización. Se dividen en:
#
# - Métodos Promediados: se basa en construir varios estimadores de forma independiente y luego promediar sus predicciones. En promedio, el estimador combinado suele ser mejor que cualquiera de los estimadores de base única porque su varianza es reducida.
#
# - Métodos de Impulso: se construyen secuencialmente y se intenta reducir el sesgo del estimador combinado. La idea es combinar varios módelos "débiles" para generar un ensamble más fuerte.

# %% [markdown]
# # Aplicando Gradient Boosting Classifier
#
# Este método pertenece al grupo de los métodos de impulso, permite tanto clasificación binaria como de multiples clases.

# %% [markdown]
# Hacemos el llamado de las librerías necesarias

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# En este caso vamos a indicar en el hiper-parámetro n_estimators un valor de 50 estimadores como aprendices débiles (weak learners)

# %%
gbc = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0, max_depth=1, random_state=0)

# %% [markdown]
# Otros hiper-parámetros como max_depth controla la profundidad del árbol y max_leaf_nodes el número de hojas.

# %% [markdown]
# Entrenamos el modelo, con los datos de entrenamiento y pruebas previamente divido.

# %%
gbc.fit(features_training, target_training)

# %% [markdown]
# Calculamos la métrica accuracy para nuestro modelo

# %%
gbc.score(feature_test, target_test)

# %% [markdown]
# El dato de accuracy que nos esta dando el modelo es bastante aceptable, sin embargo podemos hacer algunos ajustes en los hiper-parámetros para tratar de mejorar esta métrica.

# %%
gbc.set_params(n_estimators=200, warm_start=True)

# %% [markdown]
# En este caso utilizamos el hiper-parámetro warm_star para poder agregar más estimadores al modelo.
#
# Volvemos a entrenar nuestro modelo ahora con n_estimators = 200

# %%
gbc.fit(features_training, target_training)

# %% [markdown]
# Calculamos nuevamente el accuracy

# %%
gbc.score(feature_test, target_test)

# %% [markdown]
# Como podemos observar el dato del accuracy mejoró, por lo cual podermos determinar que al aplicar Gradient Boosting Classifier para nuestro set de datos de los hongos generaliza de una forma adecuada.
